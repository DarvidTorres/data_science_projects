# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# %xmode Plain
# Out:
# Exception reporting mode: Plain

# %%
import pandas as pd
import pycaret.classification as clf
import plotly.express as px

# %%
lending_data_raw_df = pd.read_csv("Loan_Default_Scoring_App\data_science_projects\Loan_Default_Scoring_App\data\lending_club.csv")

# %%
df = lending_data_raw_df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   funded_amnt                 9857 non-null   int64
#  1   term                        9857 non-null   object
#  2   int_rate                    9857 non-null   float64
#  3   sub_grade                   9857 non-null   object
#  4   addr_state                  9857 non-null   object
#  5   verification_status         9857 non-null   object
#  6   annual_inc                  9857 non-null   float64
#  7   emp_length                  9857 non-null   object
#  8   delinq_2yrs                 9857 non-null   int64
#  9   inq_last_6mths              9857 non-null   int64
#  10  revol_util                  9857 non-null   float64
#  11  acc_now_delinq              9857 non-null   int64
#  12  open_il_6m                  9857 non-null   int64
#  13  open_il_12m                 9857 non-null   int64
#  14  open_il_24m                 9857 non-null   int64
#  15  total_bal_il                9857 non-null   int64
#  16  all_util                    9857 non-null   int64
#  17  inq_fi                      9857 non-null   int64
#  18  inq_last_12m                9857 non-null   int64
#  19  delinq_amnt                 9857 non-null   int64
#  20  num_il_tl                   9857 non-null   int64
#  21  total_il_high_credit_limit  9857 non-null   int64
#  22  Class                       9857 non-null   object
# dtypes: float64(3), int64(14), object(6)
# memory usage: 1.7+ MB

# %%
float_cols = df.select_dtypes(include="float64").columns.to_list()

int_cols = df.select_dtypes(include="int64").columns.to_list()

numeric_columns = [*float_cols, *int_cols]

# %%
cat_columns = df.select_dtypes('object').drop("Class", axis=1).columns.to_list()

# %%
clf_1 = clf.setup(
    data       = df, 
    target     = "Class",
    train_size = 0.8,
    session_id = 123,
    
    categorical_features=cat_columns,
    numeric_features=numeric_columns
    
)
# Out:
# <style  type="text/css" >
# #T_39c74466_f64a_11ee_9f52_00155db289c4row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_39c74466_f64a_11ee_9f52_00155db289c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row1_col1" class="data row1 col1" >Class</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row3_col1" class="data row3 col1" >bad: 0, good: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row4_col1" class="data row4 col1" >(9857, 23)</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row6_col1" class="data row6 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row11_col1" class="data row11 col1" >(7885, 118)</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row12_col1" class="data row12 col1" >(1972, 118)</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_39c74466_f64a_11ee_9f52_00155db289c4level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155db289c4row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_39c74466_f64a_11ee_9f52_00155d

# %%
xgb_model = clf.create_model(
    estimator = 'xgboost'
)
# Out:
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   02:28:53
# Status     . . . . . . . . . . . . . . . . . .           Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# Empty DataFrame
# Columns: [Fold, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# Traceback (most recent call last):
#
#   File "C:\Users\Darvi\AppData\Local\Temp\ipykernel_12784\4203583276.py", line 2, in <module>
#     estimator = 'xgboost'
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\pycaret\classification.py", line 969, in create_model
#     **kwargs,
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\pycaret\internal\tabular.py", line 3210, in create_model_supervised
#     error_score=0,
#
#   File "C:\Users\Darvi\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py", line 72, in inner_f
#     return f(**kwargs)
#
#   File "C:\Users\Darvi\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 1952, in __call__
#     return output if self.return_generator else list(output)
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 1595, in _get_outputs
#     yield from self._retrieve()
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 1699, in _retrieve
#     self._raise_error_fast()
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 1734, in _raise_error_fast
#     error_job.get_result(self.timeout)
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 736, in get_result
#     return self._return_or_raise()
#
#   File "c:\Users\Darvi\anaconda3\envs\Finance\lib\site-packages\joblib\parallel.py", line 754, in _return_or_raise
#     raise self._result
#
# TerminatedWorkerError: A worker process managed by the executor was unexpectedly terminated. This could be caused by a segmentation fault while calling the function or by an excessive memory usage causing the Operating System to kill the worker.
